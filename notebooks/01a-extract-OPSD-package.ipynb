# %%
from pandas_datapackage_reader import read_datapackage

# %%
df = read_datapackage('../data/external/opsd-time_series-2020-10-06/', 'opsd_time_series_15min')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Miniconda3\envs\windtask25-timeseries\lib\site-packages\pandas\core\tools\datetimes.py in _convert_listlike_datetimes(arg, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     431             try:
# --> 432                 values, tz = conversion.datetime_to_datetime64(arg)
#     433                 return DatetimeIndex._simple_new(values, name=name, tz=tz)
#
# pandas\_libs\tslibs\conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-095721415dd0> in <module>
# ...

# %%
df
# Out:
#                             cet_cest_timestamp  \
# utc_timestamp
# 2014-12-31 23:00:00  2015-01-01 00:00:00+01:00
# 2014-12-31 23:15:00  2015-01-01 00:15:00+01:00
# 2014-12-31 23:30:00  2015-01-01 00:30:00+01:00
# 2014-12-31 23:45:00  2015-01-01 00:45:00+01:00
# 2015-01-01 00:00:00  2015-01-01 01:00:00+01:00
# ...                                        ...
# 2020-09-30 22:45:00  2020-10-01 00:45:00+02:00
# 2020-09-30 23:00:00  2020-10-01 01:00:00+02:00
# 2020-09-30 23:15:00  2020-10-01 01:15:00+02:00
# 2020-09-30 23:30:00  2020-10-01 01:30:00+02:00
# 2020-09-30 23:45:00  2020-10-01 01:45:00+02:00
#
#                      AT_load_actual_entsoe_transparency  \
# utc_timestamp
# 2014-12-31 23:00:00                                 NaN
# 2014-12-31 23:15:00                                 NaN
# 2014-12-31 23:30:00                                 NaN
# 2014-12-31 23:45:00                                 NaN
# 2015-01-01 00:00:00                                 NaN
# ...
